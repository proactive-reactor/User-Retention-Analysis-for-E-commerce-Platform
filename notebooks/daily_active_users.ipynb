# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"R:\Github\User Retention Analysis for E-commerce Platform\data\DAILY ACTIVE USERS.csv")

# %%
df.head()
# Out:
#          date   dau
# 0  2016-08-01  1197
# 1  2016-08-02  1799
# 2  2016-08-03  2481
# 3  2016-08-04  2959
# 4  2016-08-05  2745

# %%
df.tail()
# Out:
#            date   dau
# 362  2017-07-29  1676
# 363  2017-07-30  1513
# 364  2017-07-31  2292
# 365  2017-08-01  2322
# 366  2017-08-02   597

# %%
df.dtypes
# Out:
# date      str
# dau     int64
# dtype: object

# %%
df.columns
# Out:
# Index(['date', 'dau'], dtype='str')

# %%
df.info
# Out:
# <bound method DataFrame.info of            date   dau
# 0    2016-08-01  1197
# 1    2016-08-02  1799
# 2    2016-08-03  2481
# 3    2016-08-04  2959
# 4    2016-08-05  2745
# ..          ...   ...
# 362  2017-07-29  1676
# 363  2017-07-30  1513
# 364  2017-07-31  2292
# 365  2017-08-01  2322
# 366  2017-08-02   597
#
# [367 rows x 2 columns]>

# %%
#convert date
df['date'] = pd.to_datetime(df['date'])

# %%
plt.plot(df['date'],df['dau'], marker='+')
plt.title('Daily ACtive Users')
plt.xlabel('Days')
plt.ylabel('Active Users')
plt.show()
